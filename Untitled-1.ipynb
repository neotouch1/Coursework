# %%
import numpy as np
from matplotlib.image import imread
import matplotlib.pyplot as plt
import os

plt.rcParams['figure.figsize'] = [5, 5]
plt.rcParams.update({'font.size': 18})

# %%
A = imread(os.path.join('..', 'DATA', '../dLHdaJ-_SZg.jpg'))
B = np.mean(A, -1)

plt.figure()
plt.imshow(A)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 637.5, -0.5)

# %%
Bt = np.fft.fft2(B)
Btsort = np.sort(np.abs(Bt.reshape(-1))) # КОнвертируем в вектор и сортируем
print(Btsort.shape)
# Out:
# (816640,)

# %%
for keep in (0.1, 0.05, 0.01, 0.002):
    thresh = Btsort[int(np.floor((1-keep)*len(Btsort)))]
    ind = np.abs(Bt) > thresh # маска для отсеивания значений коэффициентов ниже заданного процета
    Btlow = Bt * ind
    Alow = np.fft.ifft2(Btlow).real

    plt.figure()
    plt.imshow(Alow, cmap='gray')
    plt.axis('off')
    plt.title('Copressing image:' + str(keep*100) + '%')
